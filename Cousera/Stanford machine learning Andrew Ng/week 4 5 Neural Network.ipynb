# %% [markdown]
# 之前讲了linear regression logistic regression
# 现在开始讲:
# # Neural Network

# %% [markdown]
# 如果还像之前一样用各种polynomial表示feature,那么在feature增加之后,需要的polynomial排列组合增加,计算成本提高
# 如果是图像的话,每个像素点就是一个feature,那就一共有上million个排列组合的feature,只能用deep learning来解决
#
# 每一个node都可以实现基本的not and nor等逻辑,很多个note就可以决定很多像素点的共同逻辑,找到图像的pattern
#
# # Cost Function
# ![%E6%88%AA%E5%B1%8F2020-04-05%E4%B8%8A%E5%8D%8810.31.06.png](attachment:%E6%88%AA%E5%B1%8F2020-04-05%E4%B8%8A%E5%8D%8810.31.06.png)

# %% [markdown]
# # Backprogagation

# %% [markdown]
# 根据最后一步的差值,通过算倒数第二步的导数确定敏感度,来对应修改倒数第二步的weight,然后修改更之前的weights,以此类推
# 详见3Blue1Brown的视频![%E6%88%AA%E5%B1%8F2020-04-05%E4%B8%8A%E5%8D%8811.12.53.png](attachment:%E6%88%AA%E5%B1%8F2020-04-05%E4%B8%8A%E5%8D%8811.12.53.png)
