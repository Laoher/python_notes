# %% [markdown]
# # Classification

# %% [markdown]
# classification的问题要用logistic Regression 不能再用linear regression
#
# sigmoid function ==logistic function

# %% [markdown]
# # Decision Boundary

# %% [markdown]
# 有了激活函数, 产生了中间的一个threshold, 这个值构成的边界就是decision boudary

# %% [markdown]
# # Cost function

# %% [markdown]
# sigmoid function的cost function:
# ![%E6%88%AA%E5%B1%8F2020-04-03%E4%B8%8A%E5%8D%8812.09.05.png](attachment:%E6%88%AA%E5%B1%8F2020-04-03%E4%B8%8A%E5%8D%8812.09.05.png)

# %% [markdown]
#  如果将上面式子简化的话将得到:
#  (case 数量:2
#  激活函数: sigmoid)
#  ![%E6%88%AA%E5%B1%8F2020-04-04%E4%B8%8A%E5%8D%8810.12.21.png](attachment:%E6%88%AA%E5%B1%8F2020-04-04%E4%B8%8A%E5%8D%8810.12.21.png)

# %% [markdown]
# ![%E6%88%AA%E5%B1%8F2020-04-04%E4%B8%8A%E5%8D%8810.54.14.png](attachment:%E6%88%AA%E5%B1%8F2020-04-04%E4%B8%8A%E5%8D%8810.54.14.png)

# %% [markdown]
# optimization algorithm:
# - gradient descent
# - Conjugate gradient
# - BFGS
# - L-BFGS
#
# 除了gradient descent 还设有其他的算法可以选择, 往往不需要选择alpha, 收敛也更快,但可能更复杂,如果不是专家的话,不要轻易使用m

# %% [markdown]
# # multiclass classification
# 相当于把每个class都和所有其余的分隔开的二分类, 所以一共要有n 个logistics functions

# %% [markdown]
# # overfitting

# %% [markdown]
# 为了避免overfitting, 可以:
# - 减少feature
# - 使用 regulization
# ![%E6%88%AA%E5%B1%8F2020-04-04%E4%B8%8A%E5%8D%8811.51.18.png](attachment:%E6%88%AA%E5%B1%8F2020-04-04%E4%B8%8A%E5%8D%8811.51.18.png)
# 如果λ太小就还是会overfit, 太大就会underfit
