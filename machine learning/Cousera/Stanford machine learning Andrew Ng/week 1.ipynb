# %% [markdown]
# # 要区分好问题到底是什么

# %% [markdown]
# # Supervised learning分类
#
# regression problem: 可能通过很多变量 predict a valued output       continuous
# classification problem: 也可能通过很多变量 判断是哪一种              discrete
#
# 例子
# (a) Regression - Given a picture of a person, we have to predict their age on the basis of the given picture
#
# (b) Classification - Given a patient with a tumor, we have to predict whether the tumor is malignant or benign.

# %% [markdown]
# # Unsupervised Learning分类
#
# Clustering: Take a collection of 1,000,000 different genes, and find a way to automatically group these genes into groups that are somehow similar or related by different variables, such as lifespan, location, roles, and so on.
#
# Non-clustering: The "Cocktail Party Algorithm", allows you to find structure in a chaotic environment. (i.e. identifying individual voices and music from a mesh of sounds at a cocktail party).

# %% [markdown]
# # linear Regression

# %% [markdown]
# # model representation
# 从(x,y)这组数据得到中间猜测的关系h,称之为hypothesis
# ![hypothesis.png](attachment:hypothesis.png)

# %% [markdown]
# # cost function
# Squared error function", or "Mean squared error"
# ![mean%20squared%20error.png](attachment:mean%20squared%20error.png)
# 求对应的parameter使得这个表达式的值最小
# ![%E6%88%AA%E5%B1%8F2020-03-27%E4%B8%8A%E5%8D%8812.12.03.png](attachment:%E6%88%AA%E5%B1%8F2020-03-27%E4%B8%8A%E5%8D%8812.12.03.png)
# ![%E6%88%AA%E5%B1%8F2020-03-27%E4%B8%8A%E5%8D%8812.15.05.png](attachment:%E6%88%AA%E5%B1%8F2020-03-27%E4%B8%8A%E5%8D%8812.15.05.png)
# 像这样一两个参数的可以靠画图来呈现最小值的感觉,但是高维就不行了.但目的同样都是找这个local minimum 使得cost function值最小,也就是最优解

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# gradient descent是可以用于machine learning几乎所有地方的,不只是linear regression![%E6%88%AA%E5%9C%96%202020-03-28%20%E4%B8%8B%E5%8D%883.22.06.png](attachment:%E6%88%AA%E5%9C%96%202020-03-28%20%E4%B8%8B%E5%8D%883.22.06.png)

# %% [markdown]
# 一定要用偏导数同时更新所有的参数, 而不是像右图错误的方式(一个一个更新)
# 这个alpha就是learning rate, 也就是step的大小,太大可能会错过local minimum 太小的话收敛太慢
# 由于导数在靠近minimum时会变小,超过minimum符号会变反自动往回找minimum, 所以只要保持alpha恒定就可以了,不需要随着导数变化

# %% [markdown]
# # Gradient Descent For linear regression

# %% [markdown]
# convex function: 只有一个global minimum, bowl-shaped

# %% [markdown]
# batch gradient descent
